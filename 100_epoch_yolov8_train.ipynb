# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.5/870.5 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import os
from IPython import display
display.clear_output()
# !yolo mode=checks
from ultralytics import YOLO
from IPython.display import display,Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 739, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'train', 'track', 'predict', 'val', 'benchmark', 'export'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
# ...

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="46dXYcGtvQYp5ZECTuDN")
project = rf.workspace("annotation-wiyr4").project("x-ray-annotation")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to X-ray-Annotation-10 in yolov8:: 100%|██████████| 568/568 [00:00<00:00, 3021.88it/s]

# %%
# !yolo task=segment mode=train model=yolov8l-seg.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=val model=/content/runs/segment/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 313 layers, 41,740,377 parameters, 0 gradients, 200.5 GFLOPs
# val: Scanning /content/X-ray-Annotation-10/valid/labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% 7/7 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7        233      0.867       0.81      0.821      0.493      0.784      0.705       0.69      0.367
#         mental foramen          7         14      0.686      0.625      0.583       0.21       0.57      0.475      0.424     0.0885
#          nasal channel          7         21      0.935       0.81      0.885       0.54       0.82      0.667      0.668      0.406
# ...

# %%
# !yolo task=segment mode=predict model=/content/runs/segment/train/weights/best.pt conf=0.4 source={dataset.location}/test/images
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 313 layers, 41,740,377 parameters, 0 gradients, 200.5 GFLOPs
#
# image 1/10 /content/X-ray-Annotation-10/test/images/316_png.rf.fb0b32c94c45c28eaf4eccaf19255a47.jpg: 640x640 1 mental foramen, 1 nasal channel, 32 teeths, 71.7ms
# image 2/10 /content/X-ray-Annotation-10/test/images/341_png.rf.4224eccc1f970cd0e8b421cb61ba55ac.jpg: 640x640 2 nasal channels, 26 teeths, 44.3ms
# image 3/10 /content/X-ray-Annotation-10/test/images/357_png.rf.0c08e62db3349a09a52643dfac453c75.jpg: 640x640 1 mental foramen, 2 nasal channels, 20 teeths, 44.2ms
# image 4/10 /content/X-ray-Annotation-10/test/images/397_png.rf.3cb22c2c1996be040b2b3975a0bd3e19.jpg: 640x640 2 mental foramens, 2 nasal channels, 31 teeths, 44.3ms
# image 5/10 /content/X-ray-Annotation-10/test/images/438_png.rf.d481ed19a1fafc7e16c087cfd3e6c39b.jpg: 640x640 1 mental foramen, 2 nasal channels, 30 teeths, 44.2ms
# ...
